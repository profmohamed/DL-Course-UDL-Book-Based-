# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedhemed77/DL-Course-UDL-Book-Based-/blob/main/Implementations/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression
# Why we are here ?
#
# Our target is to find a function that describe our data with satisfying error that is suitale to the type of the problem
#
# # ML = FUNCTION APPROXIMATION ,
#  as the function which all of us seeking to find is not  (exist)  :D
#
#
# We start our journy by The simplest problem is to find a function that best describe the data linearly.

# %%
#install latexfy library to show math equation with no effort
# !pip3 install latexify-py
# Out:
# Requirement already satisfied: latexify-py in /usr/local/lib/python3.11/dist-packages (0.4.4)
# Requirement already satisfied: dill>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from latexify-py) (0.3.9)

# %%
# Math library
import math
import numpy as np
# Plotting library
import matplotlib.pyplot as plt
# Display math symbols , expressions library
import latexify

# %%
# Create some input / output data
x = np.array([0.03, 0.19, 0.34, 0.46, 0.78, 0.81, 1.08, 1.18, 1.39, 1.60, 1.65, 1.90])
y = np.array([0.67, 0.85, 1.05, 1.0, 1.40, 1.5, 1.3, 1.54, 1.55, 1.68, 1.73, 1.6 ])
print(x)
print(y)
# Out:
# [0.03 0.19 0.34 0.46 0.78 0.81 1.08 1.18 1.39 1.6  1.65 1.9 ]
# [0.67 0.85 1.05 1.   1.4  1.5  1.3  1.54 1.55 1.68 1.73 1.6 ]

# %%
# Define 1D linear regression model
def f(x, phi0, phi1):
  y = x * phi1 + phi0
  return y

# %%
# Function to help plot the data
def plot(x, y, phi0, phi1):
    fig, ax = plt.subplots()
    ax.scatter(x, y, color='blue', label='Data Points')  # Scatter plot of data points

    # Set axis limits
    plt.xlim([0, 2.0])
    plt.ylim([0, 2.0])

    # Set labels
    ax.set_xlabel('Input, $x$')
    ax.set_ylabel('Output, $y$')
    # Draw line
    x_line = np.arange(0,2,0.01)
    y_line = f(x_line, phi0, phi1)
    plt.plot(x_line, y_line,'r-',lw=2)

    plt.show()

plot(x, y, phi0=0.1, phi1=1.0)

# %%
# Set the intercept and slope as in figure 2.2b
phi0 = 0.4 ; phi1 = 0.2
# Plot the data and the model
plot(x,y,phi0,phi1)

# %%
# Function to calculate the loss

@latexify.function(use_math_symbols=True)
def compute_loss(x,y,phi0,phi1):
  loss = np.sum(y - f(x,phi0,phi1)**2)
  return loss

compute_loss
# Out:
# $$ \displaystyle \begin{array}{l} \mathrm{loss} = \sum \mathopen{}\left( y - \mathopen{}\left( f \mathopen{}\left( x, \mathrm{phi0}, \mathrm{phi1} \mathclose{}\right) \mathclose{}\right)^{2} \mathclose{}\right) \\ \mathrm{compute\_loss}(x, y, \mathrm{phi0}, \mathrm{phi1}) = \mathrm{loss} \end{array} $$

# %%
# Compute the loss for our current model
loss = compute_loss(x,y,phi0,phi1)
print(f'Your Loss = {loss:3.2f}, Ground truth =7.07')
# Out:
# Your Loss = 11.52, Ground truth =7.07

# %%
# Set the intercept and slope as in figure 2.2c
phi0 = 1.60 ; phi1 =-0.8
# Plot the data and the model
plot(x,y,phi0,phi1)
loss = compute_loss(x,y,phi0,phi1)
print(f'Your Loss = {loss:3.2f}, Ground truth =10.28')
# Out:
# Your Loss = 4.75, Ground truth =10.28

# %%
# initialize wieghts :
phi0 = 1.60 ; phi1 =-0.8
plot(x,y,phi0,phi1)
print(f'Your Loss = {compute_loss(x,y,phi0,phi1):3.2f}')
# Out:
# Your Loss = 4.75

# %%
def gradient_descent(x, y, phi0, phi1, lr=0.1, iterations=100):
    for _ in range(iterations):

        d_phi0 = -2 * np.mean(y - (phi0 + phi1 * x))  # Partial derivative w.r.t. phi0
        d_phi1 = -2 * np.mean(x * (y - (phi0 + phi1 * x)))  # Partial derivative w.r.t. phi1

        phi0 -= lr * d_phi0  # Update phi0
        phi1 -= lr * d_phi1  # Update phi1

        loss = compute_loss(x, y, phi0, phi1)
        # debug print function
        print(f'phi0: {phi0:.3f}, phi1: {phi1:.3f}, Loss: {loss:.3f}')
        plot(x,y,phi0,phi1)
    return phi0, phi1

# %%
phi0, phi1 = gradient_descent(x, y, phi0, phi1)
plot(x,y,phi0,phi1)
print(f'Your Loss = {compute_loss(x,y,phi0,phi1):3.2f}')

x.shape , y.shape
# Out:
# phi0: 1.533, phi1: -0.100, Loss: -8.987
# phi0: 1.510, phi1: -0.079, Loss: -8.870
# phi0: 1.487, phi1: -0.058, Loss: -8.747
# phi0: 1.466, phi1: -0.039, Loss: -8.625
# phi0: 1.444, phi1: -0.020, Loss: -8.505
# phi0: 1.424, phi1: -0.002, Loss: -8.390
# phi0: 1.404, phi1: 0.015, Loss: -8.281
# phi0: 1.385, phi1: 0.032, Loss: -8.176
# phi0: 1.366, phi1: 0.049, Loss: -8.078
# phi0: 1.348, phi1: 0.064, Loss: -7.984
# phi0: 1.331, phi1: 0.080, Loss: -7.896
# phi0: 1.314, phi1: 0.094, Loss: -7.812
# phi0: 1.298, phi1: 0.109, Loss: -7.733
# phi0: 1.282, phi1: 0.122, Loss: -7.659
# phi0: 1.267, phi1: 0.136, Loss: -7.588
# phi0: 1.252, phi1: 0.149, Loss: -7.522
# phi0: 1.238, phi1: 0.161, Loss: -7.459
# phi0: 1.224, phi1: 0.173, Loss: -7.400
# phi0: 1.211, phi1: 0.185, Loss: -7.343
# phi0: 1.198, phi1: 0.196, Loss: -7.290
# phi0: 1.186, phi1: 0.207, Loss: -7.240
# phi0: 1.174, phi1: 0.217, Loss: -7.193
# phi0: 1.162, phi1: 0.227, Loss: -7.148
# phi0: 1.151, phi1: 0.237, Loss: -7.105
# phi0: 1.140, phi1: 0.247, Loss: -7.065
# phi0: 1.130, phi1: 0.256, Loss: -7.026
# phi0: 1.120, phi1: 0.265, Loss: -6.990
# phi0: 1.110, phi1: 0.273, Loss: -6.956
# phi0: 1.100, phi1: 0.282, Loss: -6.923
# phi0: 1.091, phi1: 0.290, Loss: -6.892
# phi0: 1.082, phi1: 0.297, Loss: -6.863
# phi0: 1.074, phi1: 0.305, Loss: -6.835
# phi0: 1.066, phi1: 0.312, Loss: -6.809
# phi0: 1.058, phi1: 0.319, Loss: -6.784
# phi0: 1.050, phi1: 0.326, Loss: -6.760
# phi0: 1.043, phi1: 0.332, Loss: -6.738
# phi0: 1.035, phi1: 0.339, Loss: -6.716
# phi0: 1.028, phi1: 0.345, Loss: -6.696
# phi0: 1.022, phi1: 0.351, Loss: -6.676
# phi0: 1.015, phi1: 0.356, Loss: -6.658
# phi0: 1.009, phi1: 0.362, Loss: -6.640
# phi0: 1.003, phi1: 0.367, Loss: -6.624
# phi0: 0.997, phi1: 0.372, Loss: -6.608
# phi0: 0.991, phi1: 0.377, Loss: -6.593
# phi0: 0.986, phi1: 0.382, Loss: -6.578
# phi0: 0.980, phi1: 0.387, Loss: -6.565
# phi0: 0.975, phi1: 0.391, Loss: -6.552
# phi0: 0.970, phi1: 0.396, Loss: -6.539
# phi0: 0.965, phi1: 0.400, Loss: -6.527
# phi0: 0.961, phi1: 0.404, Loss: -6.516
# phi0: 0.956, phi1: 0.408, Loss: -6.505
# phi0: 0.952, phi1: 0.412, Loss: -6.495
# phi0: 0.948, phi1: 0.415, Loss: -6.485
# phi0: 0.944, phi1: 0.419, Loss: -6.476
# phi0: 0.940, phi1: 0.422, Loss: -6.467
# phi0: 0.936, phi1: 0.426, Loss: -6.458
# phi0: 0.932, phi1: 0.429, Loss: -6.450
# phi0: 0.929, phi1: 0.432, Loss: -6.442
# phi0: 0.925, phi1: 0.435, Loss: -6.435
# phi0: 0.922, phi1: 0.438, Loss: -6.427
# phi0: 0.919, phi1: 0.441, Loss: -6.421
# phi0: 0.916, phi1: 0.443, Loss: -6.414
# phi0: 0.913, phi1: 0.446, Loss: -6.408
# phi0: 0.910, phi1: 0.449, Loss: -6.402
# phi0: 0.907, phi1: 0.451, Loss: -6.396
# phi0: 0.904, phi1: 0.453, Loss: -6.391
# phi0: 0.902, phi1: 0.456, Loss: -6.385
# phi0: 0.899, phi1: 0.458, Loss: -6.380
# phi0: 0.897, phi1: 0.460, Loss: -6.375
# phi0: 0.894, phi1: 0.462, Loss: -6.371
# phi0: 0.892, phi1: 0.464, Loss: -6.366
# phi0: 0.890, phi1: 0.466, Loss: -6.362
# phi0: 0.888, phi1: 0.468, Loss: -6.358
# phi0: 0.886, phi1: 0.470, Loss: -6.354
# phi0: 0.884, phi1: 0.472, Loss: -6.350
# phi0: 0.882, phi1: 0.473, Loss: -6.347
# phi0: 0.880, phi1: 0.475, Loss: -6.343
# phi0: 0.878, phi1: 0.476, Loss: -6.340
# phi0: 0.876, phi1: 0.478, Loss: -6.337
# phi0: 0.875, phi1: 0.479, Loss: -6.334
# phi0: 0.873, phi1: 0.481, Loss: -6.331
# phi0: 0.872, phi1: 0.482, Loss: -6.328
# phi0: 0.870, phi1: 0.484, Loss: -6.325
# phi0: 0.869, phi1: 0.485, Loss: -6.323
# phi0: 0.867, phi1: 0.486, Loss: -6.320
# phi0: 0.866, phi1: 0.487, Loss: -6.318
# phi0: 0.864, phi1: 0.488, Loss: -6.315
# phi0: 0.863, phi1: 0.490, Loss: -6.313
# phi0: 0.862, phi1: 0.491, Loss: -6.311
# phi0: 0.861, phi1: 0.492, Loss: -6.309
# phi0: 0.860, phi1: 0.493, Loss: -6.307
# phi0: 0.858, phi1: 0.494, Loss: -6.305
# phi0: 0.857, phi1: 0.495, Loss: -6.303
# phi0: 0.856, phi1: 0.496, Loss: -6.301
# phi0: 0.855, phi1: 0.496, Loss: -6.300
# phi0: 0.854, phi1: 0.497, Loss: -6.298
# phi0: 0.853, phi1: 0.498, Loss: -6.296
# phi0: 0.853, phi1: 0.499, Loss: -6.295
# phi0: 0.852, phi1: 0.500, Loss: -6.294
# phi0: 0.851, phi1: 0.500, Loss: -6.292
# Your Loss = -6.29
# ((12,), (12,))
