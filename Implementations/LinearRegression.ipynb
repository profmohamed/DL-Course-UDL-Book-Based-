# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedhemed77/DL-Course-UDL-Book-Based-/blob/main/Implementations/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install latexify-py
# Out:
# Collecting latexify-py
#   Downloading latexify_py-0.4.4-py3-none-any.whl.metadata (4.2 kB)
# Collecting dill>=0.3.2 (from latexify-py)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Downloading latexify_py-0.4.4-py3-none-any.whl (38 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: dill, latexify-py
# Successfully installed dill-0.3.9 latexify-py-0.4.4

# %%
import math
import latexify

# %%
@latexify.function
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
sigmoid
# Out:
# $$ \displaystyle \mathrm{sigmoid}(x) = \frac{1}{1 + \exp \mathopen{}\left( -x \mathclose{}\right)} $$

# %%
@latexify.expression
def sigmoid(x):
  return 1 / (1 + math.exp(-x))
sigmoid
# Out:
# $$ \displaystyle \frac{1}{1 + \exp \mathopen{}\left( -x \mathclose{}\right)} $$

# %%
@latexify.function(identifiers={'sigmoid':'sigma'}, use_math_symbols=True)
def sigmoid(x):
  return 1 / (1 + math.exp(-x))
sigmoid
# Out:
# $$ \displaystyle \sigma(x) = \frac{1}{1 + \exp \mathopen{}\left( -x \mathclose{}\right)} $$

# %%
@latexify.expression(use_math_symbols=True)

def trigfunction(theta):
  return math.sin(theta) + math.cos(2*theta)

trigfunction
# Out:
# $$ \displaystyle \sin \theta + \cos \mathopen{}\left( 2 \theta \mathclose{}\right) $$

# %%
import numpy as np

@latexify.algorithmic(use_math_symbols=True)
def relu(x):
    return np.maximum(0, x)

relu
# Out:
# $ \begin{array}{l} \mathbf{function} \ \mathrm{relu}(x) \\ \hspace{1em} \mathbf{return} \ \mathrm{np}.\mathrm{maximum} \mathopen{}\left( 0, x \mathclose{}\right) \\ \mathbf{end \ function} \end{array} $

# %%
@latexify.function(identifiers = {'fib_recursive' : 'fib'} )
def fib_recursive(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fib_recursive(n - 1) + fib_recursive(n - 2)
fib_recursive
# Out:
# $$ \displaystyle \mathrm{fib}(n) = \left\{ \begin{array}{ll} 0, & \mathrm{if} \ n \le 0 \\ 1, & \mathrm{if} \ n = 1 \\ \mathrm{fib} \mathopen{}\left( n - 1 \mathclose{}\right) + \mathrm{fib} \mathopen{}\left( n - 2 \mathclose{}\right), & \mathrm{otherwise} \end{array} \right. $$

# %%
@latexify.algorithmic(identifiers = {'fib_recursive' : 'fib'} )
def fib_recursive(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fib_recursive(n - 1) + fib_recursive(n - 2)
fib_recursive
# Out:
# $ \begin{array}{l} \mathbf{function} \ \mathrm{fib}(n) \\ \hspace{1em} \mathbf{if} \ n \le 0 \\ \hspace{2em} \mathbf{return} \ 0 \\ \hspace{1em} \mathbf{else} \\ \hspace{2em} \mathbf{if} \ n = 1 \\ \hspace{3em} \mathbf{return} \ 1 \\ \hspace{2em} \mathbf{else} \\ \hspace{3em} \mathbf{return} \ \mathrm{fib} \mathopen{}\left( n - 1 \mathclose{}\right) + \mathrm{fib} \mathopen{}\left( n - 2 \mathclose{}\right) \\ \hspace{2em} \mathbf{end \ if} \\ \hspace{1em} \mathbf{end \ if} \\ \mathbf{end \ function} \end{array} $

# %%
# LinearRegression
# Why we are here ?
# Our target is to find a function that describe our data with satisfying error that is suitale to the type of the problem
# ML = FUNCTION APPROXIMATION , as the function which all of us seeking to find is not exist :D
# The simplest problem is to find a function that best describe the data linearly

# %%
# Math library
import numpy as np
# Plotting library
import matplotlib.pyplot as plt

# %%
# Create some input / output data
x = np.array([0.03, 0.19, 0.34, 0.46, 0.78, 0.81, 1.08, 1.18, 1.39, 1.60, 1.65, 1.90])
y = np.array([0.67, 0.85, 1.05, 1.0, 1.40, 1.5, 1.3, 1.54, 1.55, 1.68, 1.73, 1.6 ])
print(x)
print(y)
# Out:
# [0.03 0.19 0.34 0.46 0.78 0.81 1.08 1.18 1.39 1.6  1.65 1.9 ]
# [0.67 0.85 1.05 1.   1.4  1.5  1.3  1.54 1.55 1.68 1.73 1.6 ]

# %%
# Define 1D linear regression model
def f(x, phi0, phi1):
  y = x * phi1 + phi0
  return y

# %%
# Function to help plot the data
def plot(x, y, phi0, phi1):
    fig, ax = plt.subplots()
    ax.scatter(x, y, color='blue', label='Data Points')  # Scatter plot of data points

    # Set axis limits
    plt.xlim([0, 2.0])
    plt.ylim([0, 2.0])

    # Set labels
    ax.set_xlabel('Input, $x$')
    ax.set_ylabel('Output, $y$')
    # Draw line
    x_line = np.arange(0,2,0.01)
    y_line = f(x_line, phi0, phi1)
    plt.plot(x_line, y_line,'r-',lw=2)

    plt.show()

plot(x, y, phi0=0.1, phi1=1.0)

# %%
# Set the intercept and slope as in figure 2.2b
phi0 = 0.4 ; phi1 = 0.2
# Plot the data and the model
plot(x,y,phi0,phi1)

# %%
# Function to calculate the loss

@latexify.function(use_math_symbols=True)
def compute_loss(x,y,phi0,phi1):
  loss = np.sum(y - f(x,phi0,phi1)**2)
  return loss

compute_loss
# Out:
# $$ \displaystyle \begin{array}{l} \mathrm{loss} = \sum \mathopen{}\left( y - \mathopen{}\left( f \mathopen{}\left( x, \mathrm{phi0}, \mathrm{phi1} \mathclose{}\right) \mathclose{}\right)^{2} \mathclose{}\right) \\ \mathrm{compute\_loss}(x, y, \mathrm{phi0}, \mathrm{phi1}) = \mathrm{loss} \end{array} $$

# %%
# Compute the loss for our current model
loss = compute_loss(x,y,phi0,phi1)
print(f'Your Loss = {loss:3.2f}, Ground truth =7.07')
# Out:
# Your Loss = 11.52, Ground truth =7.07

# %%
# Set the intercept and slope as in figure 2.2c
phi0 = 1.60 ; phi1 =-0.8
# Plot the data and the model
plot(x,y,phi0,phi1)
loss = compute_loss(x,y,phi0,phi1)
print(f'Your Loss = {loss:3.2f}, Ground truth =10.28')
# Out:
# Your Loss = 4.75, Ground truth =10.28

# %%
# initialize wieghts :
phi0 = 1.60 ; phi1 =-0.8
plot(x,y,phi0,phi1)
print(f'Your Loss = {compute_loss(x,y,phi0,phi1):3.2f}')
# Out:
# Your Loss = 4.75

# %%
def gradient_descent(x, y, phi0, phi1, lr=0.01, iterations=10):
    for _ in range(iterations):

        d_phi0 = -2 * np.mean(y - (phi0 + phi1 * x))  # Partial derivative w.r.t. phi0
        d_phi1 = -2 * np.mean(x * (y - (phi0 + phi1 * x)))  # Partial derivative w.r.t. phi1

        phi0 -= lr * d_phi0  # Update phi0
        phi1 -= lr * d_phi1  # Update phi1

        loss = compute_loss(x, y, phi0, phi1)
        # debug print function
        print(f'phi0: {phi0:.3f}, phi1: {phi1:.3f}, Loss: {loss:.3f}')

    return phi0, phi1

# %%
phi0, phi1 = gradient_descent(x, y, phi0, phi1)
plot(x,y,phi0,phi1)
print(f'Your Loss = {compute_loss(x,y,phi0,phi1):3.2f}')

x.shape , y.shape
# Out:
# phi0: 0.826, phi1: 0.522, Loss: -6.253
# phi0: 0.826, phi1: 0.522, Loss: -6.253
# phi0: 0.826, phi1: 0.522, Loss: -6.253
# phi0: 0.826, phi1: 0.522, Loss: -6.253
# phi0: 0.826, phi1: 0.522, Loss: -6.253
# phi0: 0.826, phi1: 0.522, Loss: -6.253
# phi0: 0.826, phi1: 0.522, Loss: -6.253
# phi0: 0.826, phi1: 0.522, Loss: -6.253
# phi0: 0.826, phi1: 0.522, Loss: -6.253
# phi0: 0.826, phi1: 0.522, Loss: -6.253
# Your Loss = -6.25
# ((12,), (12,))
