# %% [markdown]
# # **Lab 1 - Python Revision**

# %% [markdown]
# # Python
# Python is commonly used for developing websites and software, task automation, data analysis, and data visualization.

# %% [markdown]
# ## Lists
# A list is the Python equivalent of an array, but is resizable and can contain elements of different types:

# %%
animals = ['cat', 'dog', 'monkey']
for idx, animal in enumerate(animals):
    print('#%d: %s' % (idx + 1, animal))
# Out:
# #1: cat
# #2: dog
# #3: monkey

# %%
numbers = [1, 2, 3, 4, 5]
numbers.append(6) # adds 6 to the end
numbers.insert(0, 6) # adds 6 at index position of 0
numbers.remove(6) # removes 6
numbers.pop() # removes the last item
numbers.clear() # removes all the items
numbers.index(3) # returns the index of first occurrence of 8
numbers.sort() # sorts the list
numbers.reverse() # reverses the list
numbers.copy()

# %% [markdown]
# ## List Comprehension

# %%
nums = [0, 1, 2, 3, 4]
squares = []
for x in nums:
    squares.append(x ** 2)
print(squares)   # Prints [0, 1, 4, 9, 16]

nums = [0, 1, 2, 3, 4]
squares = [x ** 2 for x in nums]
print(squares)   # Prints [0, 1, 4, 9, 16]

nums = [0, 1, 2, 3, 4]
even_squares = [x ** 2 for x in nums if x % 2 == 0]
print(even_squares)  # Prints "[0, 4, 16]"

# %% [markdown]
# ## Dictionaries
#
# A dictionary stores (key, value) pairs, similar to a Map in Java or an object in Javascript. You can use it like this:

# %%
d = {'cat': 'cute', 'dog': 'furry'}  # Create a new dictionary with some data
print(d['cat'])       # Get an entry from a dictionary; prints "cute"
print('cat' in d)     # Check if a dictionary has a given key; prints "True"
d['fish'] = 'wet'     # Set an entry in a dictionary
print(d['fish'])      # Prints "wet"
# print(d['monkey'])  # KeyError: 'monkey' not a key of d
print(d.get('monkey', 'N/A'))  # Get an element with a default; prints "N/A"
print(d.get('fish', 'N/A'))    # Get an element with a default; prints "wet"
del d['fish']         # Remove an element from a dictionary
print(d.get('fish', 'N/A')) # "fish" is no longer a key; prints "N/A"

# %%
d = {'person': 2, 'cat': 4, 'spider': 8}
for animal in d:
    legs = d[animal]
    print('A %s has %d legs' % (animal, legs))
# Prints "A person has 2 legs", "A cat has 4 legs", "A spider has 8 legs"
# Out:
# A person has 2 legs
# A cat has 4 legs
# A spider has 8 legs

# %%
d = {'person': 2, 'cat': 4, 'spider': 8}
for animal, legs in d.items():
    print('A %s has %d legs' % (animal, legs))
# Prints "A person has 2 legs", "A cat has 4 legs", "A spider has 8 legs"
# Out:
# A person has 2 legs
# A cat has 4 legs
# A spider has 8 legs

# %% [markdown]
# ### Dictionary comprehensions:
# These are similar to list comprehensions, but allow you to easily construct dictionaries. For example

# %%
nums = [0, 1, 2, 3, 4]
even_num_to_square = {x: x ** 2 for x in nums if x % 2 == 0}
print(even_num_to_square)  # Prints "{0: 0, 2: 4, 4: 16}"
# Out:
# {0: 0, 2: 4, 4: 16}

# %% [markdown]
# ## Tuples
# A tuple is an (immutable) ordered list of values. A tuple is in many ways similar to a list; one of the most important differences is that tuples can be used as keys in dictionaries and as elements of sets, while lists cannot. Here is an example:

# %%
d = {(x, x + 1): x for x in range(10)}  # Create a dictionary with tuple keys
print(d)
t = (5, 6)        # Create a tuple
print(type(t))    # Prints "<class 'tuple'>"
print(d[t])       # Prints "5"
print(d[(1, 2)])  # Prints "1"
# Out:
# {(0, 1): 0, (1, 2): 1, (2, 3): 2, (3, 4): 3, (4, 5): 4, (5, 6): 5, (6, 7): 6, (7, 8): 7, (8, 9): 8, (9, 10): 9}
# <class 'tuple'>
# 5
# 1

# %% [markdown]
# # *Numpy*

# %% [markdown]
# NumPy is a Python library that provides a simple yet powerful data structure: the n-dimensional array. This is the foundation on which almost all the power of Python’s data science toolkit is built
# Since you already know Python, you may be asking yourself if you really have to learn a whole new paradigm to do data science. Python’s for loops are awesome! Reading and writing CSV files can be done with traditional code. However, there are some convincing arguments for learning a new paradigm.
#
# Here are the top four benefits that NumPy can bring to your code:
#
# 1. **More speed**: NumPy uses algorithms written in C that complete in nanoseconds rather than seconds.
# 2. **Fewer loops**: NumPy helps you to reduce loops and keep from getting tangled up in iteration indices.
# 3. **Clearer code:** Without loops, your code will look more like the equations you’re trying to calculate.
# 4. **Better quality**: There are thousands of contributors working to keep NumPy fast, friendly, and bug free.
#
#
# ### Numpy arrays
# A numpy array is a grid of values, all of the same type, and is indexed by a tuple of nonnegative integers. The number of dimensions is the rank of the array; the shape of an array is a tuple of integers giving the size of the array along each dimension.
# We can initialize numpy arrays from nested Python lists, and access elements using square brackets:

# %%
import numpy as np

a = np.array([1, 2, 3])   # Create a rank 1 array
print(type(a))            # Prints "<class 'numpy.ndarray'>"
print(a.shape)            # Prints "(3,)"
print(a[0], a[1], a[2])   # Prints "1 2 3"
a[0] = 5                  # Change an element of the array
print(a) 
b = np.array([[1,2,3],[4,5,6]])    # Create a rank 2 array
print(b.shape)                     # Prints "(2, 3)"
print(b[0, 0], b[0, 1], b[1, 0])   # Prints "1 2 4"
# Out:
# <class 'numpy.ndarray'>
# (3,)
# 1 2 3
# [5 2 3]
# (2, 3)
# 1 2 4

# %% [markdown]
# ### Datatypes
# Numpy provides a large set of numeric datatypes that you can use to construct arrays. `int8`, `int16`, `int32`, `float16`, `float32`, `float64`, the number next to the datatype means that you can store n bit number which is postive or negative  2* (n-1)  e.g. `int32`: 2*(31) Integer (-2147483648 to 2147483647)
#
# Numpy tries to guess a datatype when you create an array, but functions that construct arrays usually also include an optional argument to explicitly specify the datatype. Here is an example:

# %%
x = np.array([1, 2])   # Let numpy choose the datatype
print(x.dtype)         # Prints "int64"

x = np.array([1.0, 2.0])   # Let numpy choose the datatype
print(x.dtype)             # Prints "float64"

x = np.array([1, 2], dtype=np.int64)   # Force a particular datatype
print(x.dtype)
# Out:
# int64
# float64
# int64

# %% [markdown]
# ### Basic mathematical functions
#  operate elementwise on arrays, and are available both as operator overloads and as functions in the numpy module:

# %%
x = np.array([[1,2],[3,4]], dtype=np.float64)
y = np.array([[5,6],[7,8]], dtype=np.float64)

print(x + y)
print(np.add(x, y))

print(x - y)
print(np.subtract(x, y))

print(x * y)
print(np.multiply(x, y))

print(x / y)
print(np.divide(x, y))

print(np.sqrt(x))

# %% [markdown]
# ###  Matrix multiplication
# *is elementwise multiplication, not matrix multiplication. We instead use the dot function to compute inner products of vectors, to multiply a vector by a matrix, and to multiply matrices. dot is available both as a function in the numpy module and as an instance method of array objects:

# %%
x = np.array([[1,2],[3,4]])
y = np.array([[5,6],[7,8]])

v = np.array([9,10])
w = np.array([11, 12])

# Inner product of vectors; both produce 219
print(v.dot(w))
print(np.dot(v, w))

# Matrix / vector product; both produce the rank 1 array [29 67]
print(x.dot(v))
print(np.dot(x, v))

# Matrix / matrix product; both produce the rank 2 array
# [[19 22]
#  [43 50]]
print(x.dot(y))
print(np.dot(x, y))
# Out:
# 219
# 219
# [29 67]
# [29 67]
# [[19 22]
#  [43 50]]
# [[19 22]
#  [43 50]]

# %% [markdown]
# ## Vectorization
# A lot of times we require mathematical operations on arrays – such as array multiplication. Now, a non-vectorized way would be to do element wise multiplication by using a loop. Implementing it in such a way would result in the same multiplication operation to be done multiple times which would be a wastage of compute resources if the data size is too huge.

# %%
import random

a = [random.randint(1, 100) for _ in range(10000)]
b = [random.randint(1, 100) for _ in range(10000)]
# %timeit [i*j for i, j in zip(a,b)]
# Out:
# 887 µs ± 49.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
a = np.array([random.randint(1, 100) for _ in range(10000)])
b = np.array([random.randint(1, 100) for _ in range(10000)])
# %timeit a*b
# Out:
# 7.84 µs ± 1.62 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ## Broadcasting
# is another extension to vectorization where arrays **need not** be of the same sizes for operations to be performed on them like addition, subtraction, multiplication, etc. Let’s understand this by a very simple example of addition of an array and a scalar.

# %% [markdown]
# ![broadcasting.png](data:image/png;base64,...)

# %%
a = np.array([1, 1, 1, 1])
a + 5
# Out:
# array([6, 6, 6, 6])

# %%
a = np.ones((3,3))
b = np.ones(3)
a + b
# Out:
# array([[2., 2., 2.],
#        [2., 2., 2.],
#        [2., 2., 2.]])

# %% [markdown]
# ### Understanding Axes
#
#  a two-dimensional array has a vertical axis (axis 0) and a horizontal axis (axis 1). Lots of functions and commands in NumPy change their behavior based on which axis you tell them to process.
#
# This example will show how .max() behaves by default, with no axis argument, and how it changes functionality depending on which axis you specify when you do supply an argument
#
# In fact, many of NumPy’s functions behave this way: If no axis is specified, then they perform an operation on the entire dataset. Otherwise, they perform the operation in an axis-wise fashion.

# %%
table = np.array([
    [5, 3, 7, 1],
    [2, 6, 7 ,9],
    [1, 1, 1, 1],
    [4, 3, 2, 0],
])

print(table.max())

print(table.max(axis=0))

print(table.max(axis=1))
# Out:
# 9
# [5 6 7 9]
# [7 9 1 4]

# %% [markdown]
# ## Reshape & ravel
#
#
# `reshape` basically means, changing the shape of an array. And the shape of an array is determined by the number of elements in each dimension
#
# `ravel` flatten an array

# %% [markdown]
# ![Screenshot from 2023-02-26 00-59-12.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2023-02-26 00-59-29.png](data:image/png;base64,...)

# %% [markdown]
# ## **Pandas**

# %% [markdown]
# Pandas is a fast, powerful, flexible and easy to use python library that is used for manipulating numerical tables. In Machine Learning, Pandas is usually used for reading datasets, data analysis and feature engineering. Pandas is also compatible with different data sources:-
#
# *   Files: CSV, XLSX ... etc
# *   Databases: Oracle, Mysql ... etc
#
# Data can be represented in Pandas in 2 main objects:
#
#
# *   Series: one-dimensional labeled array. Usually Represents one column or row
# *   Dataframe: two-dimensional labeled array where the first dimension label is index and the second dimension label is column
#
#
# Pandas is compatible with numpy and native data structures in python (dictionary, list). It's very easy to switch between those formats.

# %% [markdown]
# ![python-pandas-create-dataframe.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# ### Example

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv') # reads csv file and returns a dataframe
df.head() # prints first 5 rows in the dataframe
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.describe() # prints summary of the dataframe columns
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
print(df.columns) # prints dataframe columns
print('------------------')
print(df.index) # prints the index of the dataframe (rows labels). It prints a range object because the index here is sequential from 0 to 17000
print('------------------')
print(df.dtypes) # prints the datatype of each column in the dataframe
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')
# ------------------
# RangeIndex(start=0, stop=17000, step=1)
# ------------------
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
# Add Columns
df['avg_bedrooms'] = df['total_bedrooms']/df['households']
df['avg_rooms'] = df['total_rooms']/df['households']
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  avg_bedrooms  \
# 0      1015.0       472.0         1.4936             66900.0      2.718220
# 1      1129.0       463.0         1.8200             80100.0      4.105832
# 2       333.0       117.0         1.6509             85700.0      1.487179
# 3       515.0       226.0         3.1917             73400.0      1.491150
# 4       624.0       262.0         1.9250             65500.0      1.244275
#
#    avg_rooms
# 0  11.889831
# 1  16.522678
# 2   6.153846
# 3   6.641593
# ...

# %%
# Changing Datatypes
df['avg_bedrooms'] = df['avg_bedrooms'].astype('int')
df['avg_rooms'] = df['avg_rooms'].astype('int')
print(df.dtypes)
df.head()
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# avg_bedrooms            int64
# avg_rooms               int64
# dtype: object
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value  avg_bedrooms  \
# 0      1015.0       472.0         1.4936             66900.0             2
# ...

# %%
# Number of rows and columns in dataframe
print(df.shape)
print(df.iloc[1]['longitude']) # access element at row number 1 and column 'langitude'
# print(df.iloc[17001]['longitude']) # ERROR index out of bounds
# Out:
# (17000, 11)
# -114.47

# %%
# Filtering Dataframe
df2 = df[df['avg_bedrooms'] > 1] # Filter all the rows that has number of bedrooms > 1
print(len(df2))
print(df2.index)
# Out:
# 193
# Int64Index([    0,     1,    23,    50,   110,   115,   116,   120,   138,
#               158,
#             ...
#             16733, 16765, 16770, 16801, 16823, 16834, 16850, 16854, 16868,
#             16994],
#            dtype='int64', length=193)

# %%
# loc vs iloc
print('---------------------')
print(df2.iloc[23]) # access row number 23. returns series object because it returns 1 row
print('---------------------')
print(df2.loc[23]) # access row that has index (name) = 23
print('---------------------')
print(df2.iloc[2]) # access row number 2 
print('---------------------')
# print(df2.loc[2]) # access row that has index = 2. ERROR: index 2 is not found in the dataframe
# Out:
# ---------------------
# longitude               -116.4900
# latitude                  33.8000
# housing_median_age        13.0000
# total_rooms             8789.0000
# total_bedrooms          1875.0000
# population              1274.0000
# households               688.0000
# median_income              3.7396
# median_house_value    148900.0000
# avg_bedrooms               2.0000
# avg_rooms                 12.0000
# Name: 235, dtype: float64
# ---------------------
# longitude              -114.9800
# latitude                 33.8200
# housing_median_age       15.0000
# total_rooms             644.0000
# total_bedrooms          129.0000
# population              137.0000
# households               52.0000
# median_income             3.2097
# median_house_value    71300.0000
# avg_bedrooms              2.0000
# avg_rooms                12.0000
# Name: 23, dtype: float64
# ---------------------
# longitude              -114.9800
# latitude                 33.8200
# ...

# %%
# drop column
# ERROR: returns error because the default axis is 0 which represents rows. No index called 'total_bedrooms' found in rows
df_dropped = df2.drop(['total_rooms', 'total_bedrooms'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-96b46cd0b61d> in <module>
#       1 # drop column
#       2 # ERROR: returns error because the default axis is 0 which represents rows. No index called 'total_bedrooms' found in rows
# ----> 3 df_dropped = df2.drop(['total_rooms', 'total_bedrooms'])
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
# ...

# %%
# Correct Syntax
df_dropped = df2.drop(['total_rooms', 'total_bedrooms'], axis=1)
df_dropped.columns

# %%
# drop rows
print(len(df2))
df_dropped = df2.drop(23) # dropping the row that has index = 23
print(len(df_dropped))

# %%
# Aggregation Operation (Sql like operations)
df_grouped = df.groupby("avg_bedrooms").agg({"median_income": ["min","max"],"housing_median_age" : "mean", "latitude":"count"})
df_grouped
# Out:
#              median_income          housing_median_age latitude
#                        min      max               mean    count
# avg_bedrooms
# 0                   0.4999  15.0001          30.366823     3623
# 1                   0.4999  15.0001          28.246359    13184
# 2                   0.4999  10.9704          18.860000      100
# 3                   0.5360   7.9885          18.428571       35
# 4                   1.6875  10.2948          19.000000       20
# 5                   1.7214   5.5456          15.153846       13
# 6                   0.4999   5.1314          17.875000        8
# 7                   2.1250   5.4618          15.500000        4
# 8                   0.9227   3.9375          20.500000        4
# 9                   2.4028   2.4917          22.000000        2
# 10                  3.8750   4.9750          19.500000        2
# 11                  3.1250   4.0714          15.000000        2
# ...

# %%
# Convert to numpy
df_numpy = df_grouped.to_numpy()
df_numpy

# %% [markdown]
# ## **Matplotlib**

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
#
#
# *   Create publication quality plots.
# *   Make interactive figures that can zoom, pan, update.
# *   Customize visual style and layout.
# *   Export to many file formats.

# %% [markdown]
# ## Example

# %%
#Matplotlib Line Plot
import numpy as np
import matplotlib.pyplot as plt
# Plot some numbers:
x = np.arange(1,11)
y = 2 * x + 5
plt.title("Matplotlib demo")
plt.xlabel("x axis caption")

plt.ylabel("y axis caption")
plt.plot(x,y)
plt.show()

# %%
#using pie chart to plot four sections that have different labels, sizes and colors
# Data labels, sizes, and colors are defined:
labels = 'Broccoli', 'Chocolate Cake', 'Blueberries', 'Raspberries'
sizes = [30, 330, 245, 210]
colors = ['green', 'brown', 'blue', 'red']

# Data is plotted:
plt.pie(sizes, labels=labels, colors=colors)

plt.axis('equal')
plt.title('Pie Plot')
plt.show()

# %% [markdown]
# **Matplotlib with Panda example**

# %%
#cal correlation between sub_df and total_rooms column and show the result as bar chart
from matplotlib import pyplot as plt 
sub_df = df[['population','latitude','total_bedrooms','total_rooms']]
correlation = sub_df.corr()['total_rooms'] 
plt.bar(sub_df.columns,correlation,color= 'purple')
plt.show()

# %% [markdown]
# ![1 lFZzE9PgKTRR8jlFI4EUtw.webp](data:image/webp;base64,...)
